# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size': 22})
 
# width of the bars
barWidth = 0.3
 
# Choose the height of the blue bars
interestMeans = [3.588, 4.127, 3.644]
 
# Choose the height of the cyan bars
trustMeans = [3.541, 4.154, 3.555]
 
# Choose the height of the error bars (bars1)
interestErrors = [[interestMeans[0] - 3.280, interestMeans[1] - 3.797, interestMeans[2] - 3.347], [3.896 - interestMeans[0], 4.456 - interestMeans[1], 3.941 - interestMeans[2]]]
 
# Choose the height of the error bars (bars2)
trustErrors = [[trustMeans[0] - 3.240, trustMeans[1] - 3.846, trustMeans[2] - 3.257], [3.841 - trustMeans[0], 4.462 - trustMeans[1], 3.853 - trustMeans[2]]]
 
# The x position of bars
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]    

# Create blue bars
plt.title("Mean of interest and trust, for each group of explanation in user study")
plt.bar(r1, interestMeans, width = barWidth, color = 'yellow', edgecolor = 'black', yerr=interestErrors, error_kw={'elinewidth': 4, 'capthick': 4}, capsize=20, label='interest', zorder=10)
 
# Create cyan bars
plt.bar(r2, trustMeans, width = barWidth, color = 'gray', edgecolor = 'black', yerr=trustErrors, error_kw={'elinewidth': 4, 'capthick': 4}, capsize=20, label='trust', zorder=10)
 
plt.grid(axis='y', zorder=0)

# general layout
plt.xticks([r + barWidth/2 for r in range(len(trustMeans))], ['Baseline', 'Association rules', 'Influence'])
plt.ylabel('rating')
plt.legend()
 
# Show graphic
plt.show()
fig.savefig('userstudy_res.png')
